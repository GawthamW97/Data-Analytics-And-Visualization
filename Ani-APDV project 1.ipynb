# %%
import pandas as pd
import numpy as np
import sys
import seaborn as sns
np.set_printoptions(threshold=sys.maxsize)
sns.set() 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.reset_option('future.no_silent_downcasting', True)
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("D:\\NCI Docs\\NCI LECS\\Analytics programming and data visualization\\Group project\\owid-energy-data.csv")
data.head()
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  biofuel_electricity  biofuel_share_elec  \
# ...

# %% [markdown]
# ## Data Pre-processing

# %%
data = data[data['year'] >= 1970]

# %%
data.shape
# Out:
# (13427, 129)

# %%
data.isna().sum()
# Out:
# country                                             0
# year                                                0
# iso_code                                         3105
# population                                       2430
# gdp                                              5507
# biofuel_cons_change_pct                         11637
# biofuel_cons_change_twh                         10703
# biofuel_cons_per_capita                         11092
# biofuel_consumption                             10641
# biofuel_elec_per_capita                          7857
# biofuel_electricity                              7593
# biofuel_share_elec                               7616
# biofuel_share_energy                            10724
# carbon_intensity_elec                            7592
# coal_cons_change_pct                             8447
# coal_cons_change_twh                             8337
# coal_cons_per_capita                             9015
# ...

# %%
#print(data.shape)

# %%
#columns = data.columns.tolist()

# %%
#for col in columns:
#    data=data[[col for col in df if data[col].isnull().sum() < 15000]]

# %%
#data.shape
# Out:
# (21812, 46)

# %%
#data.head()
# Out:
#          country  year iso_code  population  gdp  coal_prod_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                   NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                   NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                   NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                   NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                   NaN
#
#    coal_prod_change_twh  coal_prod_per_capita  coal_production  \
# 0                   NaN                   NaN              NaN
# 1                   NaN                   NaN              NaN
# 2                   NaN                   NaN              NaN
# 3                   NaN                   NaN              NaN
# 4                   NaN                   NaN              NaN
#
#    electricity_generation  energy_cons_change_pct  energy_cons_change_twh  \
# 0                  378.61                     NaN                     NaN
# ...

# %%
df = data.dropna(subset=['population'])

# %%
df.shape
# Out:
# (10997, 129)

# %%
df['country'] = df['country'].str.strip().str.title()

# %%
data_year = df.groupby("year")

# %%
data_year['year'].value_counts()
# Out:
# year
# 1970    117
# 1971    116
# 1972    116
# 1973    116
# 1974    116
# 1975    116
# 1976    116
# 1977    116
# 1978    116
# 1979    116
# 1980    211
# 1981    210
# 1982    210
# 1983    210
# 1984    210
# 1985    216
# 1986    217
# 1987    217
# 1988    217
# 1989    217
# 1990    225
# 1991    222
# 1992    227
# 1993    226
# 1994    227
# 1995    227
# 1996    227
# 1997    228
# 1998    228
# 1999    228
# 2000    231
# 2001    231
# 2002    231
# 2003    232
# 2004    232
# 2005    232
# 2006    231
# 2007    231
# 2008    231
# 2009    231
# 2010    231
# 2011    230
# 2012    231
# 2013    231
# 2014    231
# 2015    231
# 2016    231
# 2017    231
# 2018    231
# 2019    231
# 2020    231
# 2021    231
# 2022    223
# 2023    129
# Name: count, dtype: int64

# %%
data_1 = df[df['year'] >= 1980]

# %%
data_1.shape
# Out:
# (9836, 129)

# %%
data_sub = df[['year','country','iso_code','population','gdp']]

# %%
data_sub.head()
# Out:
#     year      country iso_code  population           gdp
# 94  1970  Afghanistan      AFG  10752973.0  1.581223e+10
# 95  1971  Afghanistan      AFG  11015853.0  1.577051e+10
# 96  1972  Afghanistan      AFG  11286753.0  1.317055e+10
# 97  1973  Afghanistan      AFG  11575308.0  1.356863e+10
# 98  1974  Afghanistan      AFG  11869881.0  1.430911e+10

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host="localhost", user="root", password="Anirane15@isro",database="")
cursor = conn.cursor()

cursor.execute("CREATE DATABASE IF NOT EXISTS energy_db")

print("Database 'energy_db' created successfully!")

# Close connection
cursor.close()
conn.close()
# Out:
# Database 'energy_db' created successfully!

# %%
conn = mysql.connector.connect(host="localhost", user="root", password="Anirane15@isro", database="energy_db")
cursor = conn.cursor()
# Create the 'countries' table
cursor.execute("""
    CREATE TABLE IF NOT EXISTS countries (
        country_id INT AUTO_INCREMENT PRIMARY KEY,
        country_name VARCHAR(255) UNIQUE,
        iso_code VARCHAR(10) UNIQUE
    )
""")

# %%
unique_countries = df[['country', 'iso_code']].drop_duplicates()
for index, row in unique_countries.iterrows():
    iso_code = row['iso_code'] if row['iso_code'] is not None else None  # Convert NaN to None
    cursor.execute("INSERT INTO countries (country_name, iso_code) VALUES (%s, %s)", (row['country'], row['iso_code']))
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File D:\Anaconda\Lib\site-packages\mysql\connector\connection_cext.py:755, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     754         query = query.encode("utf-8")
# --> 755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#     758         buffered=buffered,
#     759         raw_as_string=raw_as_string,
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Unknown column 'nan' in 'field list'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[315], line 4
#       2 for index, row in unique_countries.iterrows():
# ...
